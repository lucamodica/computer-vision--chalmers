# %%
from utils import *
import numpy as np
import scipy.io as sio

# %matplotlib inline

# %% [markdown]
# # computer exercise 1

# %%
# load data
values = sio.loadmat('data/compEx1.mat')
x2D = values['x2D']
x3D = values['x3D']

print(x2D.shape)
print(x3D.shape)
# Out:
# (3, 63)
# (4, 441)

# %%
plt.figure(figsize=(10, 10))
plot_points_2D(pflat(np.array(x2D)))

# %%
plt.figure(figsize=(11, 11))
plot_points_3D(pflat(np.array(x3D)))

# %% [markdown]
# # computer exercise 2
